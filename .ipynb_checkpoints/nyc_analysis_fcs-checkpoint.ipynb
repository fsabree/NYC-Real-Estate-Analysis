# %%
import pandas as pd 
from sqlalchemy import create_engine 
import numpy as np
import pymongo
import matplotlib.pyplot as plt
from datetime import datetime as dt
import seaborn as sns
sns.set(style="ticks", color_codes=True)
import calendar
import scipy.stats as sts

# %%
ny_sales_df['borough_name'].value_counts()
# Out:
# queens           22286
# brooklyn         20185
# manhattan        14457
# bronx             7020
# staten island     6922
# Name: borough_name, dtype: int64

# %%
ny_sales_df.dtypes
# Out:
# borough                             int64
# neighborhood                       object
# building_class_category            object
# tax_class_at_present               object
# block                               int64
# lot                                 int64
# easement                          float64
# building_class_at_present          object
# address                            object
# apartment_number                   object
# zipcode                           float64
# residential_units                  object
# commercial_units                  float64
# total_units                        object
# land_square_feet                   object
# gross_square_feet                  object
# year_built                        float64
# tax_class_at_time_of_sale           int64
# building_class_at_time_of_sale     object
# sale_price                         object
# sale_date                          object
# borough_name                       object
# dtype: object

# %%
#Convert year built value from float to integer
ny_sales_df['year_built'] = ny_sales_df['year_built'].astype('Int64')

# %%
#Convert sales price value from string to float

ny_sales_df['sale_price'] = ny_sales_df['sale_price'].str.replace(',', '').astype('int')

ny_sales_df.head()
# Out:
#    borough neighborhood  building_class_category tax_class_at_present  block  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 3        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3039
# 4        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3039
#
#    lot  easement building_class_at_present                 address  \
# 0   65       NaN                        A1        4455 PARK AVENUE
# 1   67       NaN                        A1        4451 PARK AVENUE
# 2   70       NaN                        A1        4445 PARK AVENUE
# 3   29       NaN                        A9  2327 WASHINGTON AVENUE
# 4   29       NaN                        A9     2327 WASHINGTON AVE
#
#   apartment_number  ...  commercial_units total_units  land_square_feet  \
# 0              NaN  ...               0.0           1             1,622
# 1              NaN  ...               0.0           1             1,646
# 2              NaN  ...               0.0           1             1,694
# 3              NaN  ...               0.0           1             1,095
# 4              NaN  ...               0.0           1             1,095
#
#   gross_square_feet year_built tax_class_at_time_of_sale  \
# 0             1,587       1899                         1
# 1             1,495       1899                         1
# 2             1,497       1899                         1
# 3             1,260       1910                         1
# 4             1,260       1910                         1
#
#    building_class_at_time_of_sale  sale_price  sale_date  borough_name
# 0                              A1      458000  1/31/2020         bronx
# 1                              A1      275000  3/16/2020         bronx
# 2                              A1      388500  7/23/2019         bronx
# 3                              A9      110000  12/6/2019         bronx
# 4                              A9      165000   3/2/2020         bronx
#
# [5 rows x 22 columns]

# %%
ny_sales_df.dtypes
# Out:
# borough                             int64
# neighborhood                       object
# building_class_category            object
# tax_class_at_present               object
# block                               int64
# lot                                 int64
# easement                          float64
# building_class_at_present          object
# address                            object
# apartment_number                   object
# zipcode                           float64
# residential_units                  object
# commercial_units                  float64
# total_units                        object
# land_square_feet                   object
# gross_square_feet                  object
# year_built                          Int64
# tax_class_at_time_of_sale           int64
# building_class_at_time_of_sale     object
# sale_price                          int32
# sale_date                          object
# borough_name                       object
# dtype: object

# %%
# Set the 'borough' as our index
ny_sales_df = ny_sales_df.set_index('borough')
ny_sales_df.head()
# Out:
#         neighborhood  building_class_category tax_class_at_present  block  \
# borough
# 2           BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 2           BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 2           BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 2           BATHGATE  01 ONE FAMILY DWELLINGS                    1   3039
# 2           BATHGATE  01 ONE FAMILY DWELLINGS                    1   3039
#
#          lot  easement building_class_at_present                 address  \
# borough
# 2         65       NaN                        A1        4455 PARK AVENUE
# 2         67       NaN                        A1        4451 PARK AVENUE
# 2         70       NaN                        A1        4445 PARK AVENUE
# 2         29       NaN                        A9  2327 WASHINGTON AVENUE
# 2         29       NaN                        A9     2327 WASHINGTON AVE
#
#         apartment_number  zipcode  ... commercial_units  total_units  \
# borough                            ...
# 2                    NaN  10457.0  ...              0.0            1
# 2                    NaN  10457.0  ...              0.0            1
# 2                    NaN  10457.0  ...              0.0            1
# 2                    NaN  10458.0  ...              0.0            1
# 2                    NaN  10458.0  ...              0.0            1
#
#         land_square_feet gross_square_feet year_built  \
# borough
# 2                  1,622             1,587       1899
# 2                  1,646             1,495       1899
# 2                  1,694             1,497       1899
# 2                  1,095             1,260       1910
# 2                  1,095             1,260       1910
#
#          tax_class_at_time_of_sale  building_class_at_time_of_sale sale_price  \
# borough
# 2                                1                              A1     458000
# 2                                1                              A1     275000
# 2                                1                              A1     388500
# 2                                1                              A9     110000
# 2                                1                              A9     165000
#
#          sale_date borough_name
# borough
# 2        1/31/2020        bronx
# 2        3/16/2020        bronx
# 2        7/23/2019        bronx
# 2        12/6/2019        bronx
# 2         3/2/2020        bronx
#
# [5 rows x 21 columns]

# %%
#compare home price to number of houses sold
#check median sales price trends by borough
#what homes are people buying and where

# %%
max_sales = ny_sales_df["sale_price"].max()
max_sales

# %%
min_sales = ny_sales_df["sale_price"].min()
min_sales

# %%
ny_sales_df.loc[ny_sales_df['sale_price'] < 1000]

# %%
sales_data = ny_sales_df[['borough','borough_name','neighborhood', 'sale_price','sale_date']].copy()
sales_data.head()

# %%
sales_data = ny_sales_df[['borough_name','neighborhood', 'sale_price','sale_date']].copy()
sales_data.head()
# Out:
#         borough_name neighborhood  sale_price  sale_date
# borough
# 2              bronx     BATHGATE      458000  1/31/2020
# 2              bronx     BATHGATE      275000  3/16/2020
# 2              bronx     BATHGATE      388500  7/23/2019
# 2              bronx     BATHGATE      110000  12/6/2019
# 2              bronx     BATHGATE      165000   3/2/2020

# %%
sales_data.dtypes
# Out:
# borough_name    object
# neighborhood    object
# sale_price       int32
# sale_date       object
# dtype: object

# %%
sales_data['sale_date'] = sales_data['sale_date'].astype('datetime64[ns]')

# %%
sales_data.dtypes
# Out:
# borough_name            object
# neighborhood            object
# sale_price               int32
# sale_date       datetime64[ns]
# dtype: object

# %%
sales_data['sale_month_year'] = sales_data['sale_date'].dt.strftime('%Y-%m')

# %%
sales_data.dtypes
# Out:
# borough_name               object
# neighborhood               object
# sale_price                  int32
# sale_date          datetime64[ns]
# sale_month_year            object
# dtype: object

# %%
sales_data.head()
# Out:
#         borough_name neighborhood  sale_price  sale_date sale_month_year
# borough
# 2              bronx     BATHGATE      458000 2020-01-31         2020-01
# 2              bronx     BATHGATE      275000 2020-03-16         2020-03
# 2              bronx     BATHGATE      388500 2019-07-23         2019-07
# 2              bronx     BATHGATE      110000 2019-12-06         2019-12
# 2              bronx     BATHGATE      165000 2020-03-02         2020-03

# %%
sales_data = sales_data.sort_values(by='sale_month_year')
sales_data.head()
# Out:
#         borough_name             neighborhood  sale_price  sale_date  \
# borough
# 1          manhattan              MURRAY HILL     1260000 2019-07-09
# 1          manhattan  UPPER EAST SIDE (79-96)     2152500 2019-07-17
# 1          manhattan  UPPER EAST SIDE (79-96)     3850000 2019-07-11
# 1          manhattan  UPPER EAST SIDE (79-96)     1925000 2019-07-09
# 3           brooklyn                BAY RIDGE           0 2019-07-18
#
#         sale_month_year
# borough
# 1               2019-07
# 1               2019-07
# 1               2019-07
# 1               2019-07
# 3               2019-07

# %%
sales_data['sale_month_year'] = sales_data['sale_month_year'].astype('datetime64[ns]')
sales_data.dtypes

# %%
sales_data.head()

# %%
sales_data = sales_data.sort_values(by='sale_month_year')
sales_data.head()

# %%
# Create a group based on the values in the 'maker' column
sl_month = sales_data.groupby('sale_month_year')

# Count how many times each maker appears in our group
count_sales = sl_month['sale_month_year'].count()

count_sales
# Out:
# sale_month_year
# 2019-07    6999
# 2019-08    7633
# 2019-09    6731
# 2019-10    7558
# 2019-11    6442
# 2019-12    7387
# 2020-01    7173
# 2020-02    6313
# 2020-03    5054
# 2020-04    2808
# 2020-05    3374
# 2020-06    3398
# Name: sale_month_year, dtype: int64

# %%
# Create a bar chart based off of the group series from before
colors = [
    "#1f77b4",
   
]
count_chart = count_sales.plot(kind='bar', color=colors)

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Sales Month Year")
count_chart.set_ylabel("Number of Properties Sold")


plt.show()
plt.tight_layout()

# %%
mm_yy = sl_month.groups.keys()
mm_yy
# Out:
# dict_keys(['2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06'])

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 5), sharey=True)
plt.xticks(rotation=90)
axs[0].bar(mm_yy, count_sales)
axs[1].scatter(mm_yy, count_sales)
axs[2].plot(mm_yy, count_sales)
fig.suptitle('New York Sales July 2019 - June 2020')
##plt.setp(axs.get_xticklabels(), rotation=45, ha="right",
#             rotation_mode="anchor")
plt.setp(axs[0].xticklabels(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-1c48a039f836> in <module>
#       3 axs[0].bar(mm_yy, count_sales)
#       4 axs[1].scatter(mm_yy, count_sales)
# ----> 5 axs[2].plot(mm_yy, count_sales)
#       6 fig.suptitle('New York Sales July 2019 - June 2020')
#       7 ##plt.setp(axs.get_xticklabels(), rotation=45, ha="right",
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     335
#     336         if self.axes.xaxis is not None:
# --> 337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
#     339             self.axes.yaxis.update_units(y)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1514         neednew = self.converter != converter
#    1515         self.converter = converter
# -> 1516         default = self.converter.default_units(data, self)
#    1517         if default is not None and self.units is None:
#    1518             self.set_units(default)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     105         # the conversion call stack is default_units -> axis_info -> convert
#     106         if axis.units is None:
# --> 107             axis.set_units(UnitData(data))
#     108         else:
#     109             axis.units.update(data)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     173         self._counter = itertools.count()
#     174         if data is not None:
# --> 175             self.update(data)
#     176
#     177     @staticmethod
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     208         # check if convertible to number:
#     209         convertible = True
# --> 210         for val in OrderedDict.fromkeys(data):
#     211             # OrderedDict just iterates over unique values in data.
#     212             cbook._check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'dict_keys'

# %%
tips = sns.load_dataset("sl_month")
sns.catplot(x="mm_yy", y="count_sales", data=tips);
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-44-a493dea0e038> in <module>
# ----> 1 tips = sns.load_dataset("sl_month")
#       2 sns.catplot(x="mm_yy", y="count_sales", data=tips);
#
# ~\Anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ### Data Analysis Using Combined Data

# %%
#Read csv file
ny_comb_sales_df = pd.read_csv("./static/data/CombinedData.csv",encoding='utf-8', low_memory=False)
ny_comb_sales_df.head(10)
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY   BLOCK    LOT  \
# 0      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   65.0
# 1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   67.0
# 2      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3039.0   29.0
# 3      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2912.0  130.0
# 4      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2929.0  114.0
# 5      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2929.0  128.0
# 6      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  3027.0   26.0
# 7      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  3034.0  138.0
# 8      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  3046.0   54.0
# 9      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  3047.0   17.0
#
#                  ADDRESS APARTMENT NUMBER  ZIP CODE RESIDENTIAL UNITS  \
# 0       4455 PARK AVENUE              NaN   10457.0               1.0
# 1       4451 PARK AVENUE              NaN   10457.0               1.0
# 2    2327 WASHINGTON AVE              NaN   10458.0               1.0
# 3  482 CLAREMONT PARKWAY              NaN   10457.0               2.0
# 4          3854 3 AVENUE              NaN   10457.0               2.0
# 5  559 CLAREMONT PARKWAY              NaN   10457.0               2.0
# 6    414 EAST 178 STREET              NaN   10457.0               2.0
# 7    1937 WASHINGTON AVE              NaN   10457.0               2.0
# 8   2043 BATHGATE AVENUE              NaN   10457.0               2.0
# 9      2123 BATHGATE AVE              NaN   10457.0               2.0
#
#    COMMERCIAL UNITS TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET  \
# 0               0.0         1.0            1,622             1,587
# 1               0.0         1.0            1,646             1,495
# 2               0.0         1.0            1,095             1,260
# 3               0.0         2.0            2,000             2,400
# 4               0.0         2.0            2,883             2,394
# 5               0.0         2.0            2,361             2,394
# 6               0.0         2.0            2,000             2,364
# 7               0.0         2.0            2,250             3,204
# 8               0.0         2.0            2,483             1,512
# 9               0.0         2.0            2,500             1,404
#
#    YEAR BUILT  TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  \
# 0      1899.0                        1.0                             A1
# 1      1899.0                        1.0                             A1
# 2      1910.0                        1.0                             A9
# 3      1993.0                        1.0                             B1
# 4      1995.0                        1.0                             B1
# 5      1995.0                        1.0                             B1
# 6      1899.0                        1.0                             B2
# 7      1995.0                        1.0                             B1
# 8      1901.0                        1.0                             B2
# 9      1901.0                        1.0                             B3
#
#   SALE PRICE    SALEDATE
# 0    458,000  2020-01-31
# 1    275,000  2020-03-16
# 2    165,000  2020-03-02
# 3          0  2020-03-17
# 4          0  2020-04-06
# 5          0  2020-02-26
# 6    734,000  2020-04-22
# 7    645,000  2020-01-28
# 8    461,370  2020-01-27
# 9    629,000  2020-04-24

# %%
#Update column names to lowercase and remove spaces
ny_comb_sales_df.columns = ['borough','neighborhood','building_class_category',
                       'block','lot','address','apartment_number',
                       'zipcode','residential_units','commercial_units','total_units','land_square_feet',
                       'gross_square_feet','year_built','tax_class_at_time_of_sale','building_class_at_time_of_sale',
                       'sale_price','sale_date']
ny_comb_sales_df.head()
# Out:
#    borough neighborhood  building_class_category   block    lot  \
# 0      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   65.0
# 1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   67.0
# 2      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3039.0   29.0
# 3      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2912.0  130.0
# 4      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2929.0  114.0
#
#                  address apartment_number  zipcode residential_units  \
# 0       4455 PARK AVENUE              NaN  10457.0               1.0
# 1       4451 PARK AVENUE              NaN  10457.0               1.0
# 2    2327 WASHINGTON AVE              NaN  10458.0               1.0
# 3  482 CLAREMONT PARKWAY              NaN  10457.0               2.0
# 4          3854 3 AVENUE              NaN  10457.0               2.0
#
#    commercial_units total_units land_square_feet gross_square_feet  \
# 0               0.0         1.0            1,622             1,587
# 1               0.0         1.0            1,646             1,495
# 2               0.0         1.0            1,095             1,260
# 3               0.0         2.0            2,000             2,400
# 4               0.0         2.0            2,883             2,394
#
#    year_built  tax_class_at_time_of_sale building_class_at_time_of_sale  \
# 0      1899.0                        1.0                             A1
# 1      1899.0                        1.0                             A1
# 2      1910.0                        1.0                             A9
# 3      1993.0                        1.0                             B1
# 4      1995.0                        1.0                             B1
#
#   sale_price   sale_date
# 0    458,000  2020-01-31
# 1    275,000  2020-03-16
# 2    165,000  2020-03-02
# 3          0  2020-03-17
# 4          0  2020-04-06

# %%
ny_comb_sales_df['borough'].value_counts()
# Out:
# 4.0    115915
# 3.0    104416
# 1.0     79356
# 5.0     37284
# 2.0     33380
# Name: borough, dtype: int64

# %%
ny_comb_sales_df.dtypes
# Out:
# borough                           float64
# neighborhood                       object
# building_class_category            object
# block                             float64
# lot                               float64
# address                            object
# apartment_number                   object
# zipcode                           float64
# residential_units                  object
# commercial_units                  float64
# total_units                        object
# land_square_feet                   object
# gross_square_feet                  object
# year_built                        float64
# tax_class_at_time_of_sale         float64
# building_class_at_time_of_sale     object
# sale_price                         object
# sale_date                          object
# dtype: object

# %%
#Convert year built value from float to integer
ny_comb_sales_df['year_built'] = ny_comb_sales_df['year_built'].astype('Int64')
ny_comb_sales_df['borough'] = ny_comb_sales_df['borough'].astype('Int64')

# %%
ny_comb_sales_df.head()
# Out:
#    borough neighborhood  building_class_category   block    lot  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   65.0
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   67.0
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS  3039.0   29.0
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS  2912.0  130.0
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS  2929.0  114.0
#
#                  address apartment_number  zipcode residential_units  \
# 0       4455 PARK AVENUE              NaN  10457.0               1.0
# 1       4451 PARK AVENUE              NaN  10457.0               1.0
# 2    2327 WASHINGTON AVE              NaN  10458.0               1.0
# 3  482 CLAREMONT PARKWAY              NaN  10457.0               2.0
# 4          3854 3 AVENUE              NaN  10457.0               2.0
#
#    commercial_units total_units land_square_feet gross_square_feet  \
# 0               0.0         1.0            1,622             1,587
# 1               0.0         1.0            1,646             1,495
# 2               0.0         1.0            1,095             1,260
# 3               0.0         2.0            2,000             2,400
# 4               0.0         2.0            2,883             2,394
#
#    year_built  tax_class_at_time_of_sale building_class_at_time_of_sale  \
# 0        1899                        1.0                             A1
# 1        1899                        1.0                             A1
# 2        1910                        1.0                             A9
# 3        1993                        1.0                             B1
# 4        1995                        1.0                             B1
#
#   sale_price   sale_date
# 0    458,000  2020-01-31
# 1    275,000  2020-03-16
# 2    165,000  2020-03-02
# 3          0  2020-03-17
# 4          0  2020-04-06

# %%
yoy_sales = ny_comb_sales_df.loc[ny_comb_sales_df['sale_date'] >= '2019-01-01']
yoy_sales.head()
# Out:
#    borough neighborhood  building_class_category   block    lot  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   65.0
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   67.0
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS  3039.0   29.0
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS  2912.0  130.0
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS  2929.0  114.0
#
#                  address apartment_number  zipcode residential_units  \
# 0       4455 PARK AVENUE              NaN  10457.0               1.0
# 1       4451 PARK AVENUE              NaN  10457.0               1.0
# 2    2327 WASHINGTON AVE              NaN  10458.0               1.0
# 3  482 CLAREMONT PARKWAY              NaN  10457.0               2.0
# 4          3854 3 AVENUE              NaN  10457.0               2.0
#
#    commercial_units total_units land_square_feet gross_square_feet  \
# 0               0.0         1.0            1,622             1,587
# 1               0.0         1.0            1,646             1,495
# 2               0.0         1.0            1,095             1,260
# 3               0.0         2.0            2,000             2,400
# 4               0.0         2.0            2,883             2,394
#
#    year_built  tax_class_at_time_of_sale building_class_at_time_of_sale  \
# 0        1899                        1.0                             A1
# 1        1899                        1.0                             A1
# 2        1910                        1.0                             A9
# 3        1993                        1.0                             B1
# 4        1995                        1.0                             B1
#
#   sale_price   sale_date
# 0    458,000  2020-01-31
# 1    275,000  2020-03-16
# 2    165,000  2020-03-02
# 3          0  2020-03-17
# 4          0  2020-04-06

# %%
yoy_sales_df = yoy_sales[['borough','neighborhood','building_class_category','gross_square_feet','year_built', 'sale_price','sale_date']]
yoy_sales_df.head()
# Out:
#    borough neighborhood  building_class_category gross_square_feet  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,587
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,495
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,260
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,400
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,394
#
#    year_built sale_price   sale_date
# 0        1899    458,000  2020-01-31
# 1        1899    275,000  2020-03-16
# 2        1910    165,000  2020-03-02
# 3        1993          0  2020-03-17
# 4        1995          0  2020-04-06

# %%
len(yoy_sales_df.index)
# Out:
# 110838

# %%
yoy_sales_df['sale_price'] = yoy_sales_df['sale_price'].str.replace(',', '').astype('int64')
yoy_sales_df.head()
# Out:
# C:\Users\FSABR\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    borough neighborhood  building_class_category gross_square_feet  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,587
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,495
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,260
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,400
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,394
#
#    year_built  sale_price   sale_date
# 0        1899      458000  2020-01-31
# 1        1899      275000  2020-03-16
# 2        1910      165000  2020-03-02
# 3        1993           0  2020-03-17
# 4        1995           0  2020-04-06

# %%
#add new column borough name based on the value in the borough field

def func(row):
    if row['borough'] == 1:
        return 'manhattan'
    elif row['borough'] ==2:
        return 'bronx'
    elif row['borough'] ==3:
        return 'brooklyn'
    elif row['borough'] ==4:
        return 'queens'
    elif row['borough'] ==5:
        return 'staten island'
    else:
        return 'other'

yoy_sales_df['borough_name'] = yoy_sales_df.apply(func, axis=1)
yoy_sales_df.head()
# Out:
# C:\Users\FSABR\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    borough neighborhood  building_class_category gross_square_feet  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,587
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,495
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,260
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,400
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,394
#
#    year_built  sale_price   sale_date borough_name
# 0        1899      458000  2020-01-31        bronx
# 1        1899      275000  2020-03-16        bronx
# 2        1910      165000  2020-03-02        bronx
# 3        1993           0  2020-03-17        bronx
# 4        1995           0  2020-04-06        bronx

# %%
yoy_sales_df['sale_date'] = yoy_sales_df['sale_date'].astype('datetime64[ns]')
# Out:
# C:\Users\FSABR\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yoy_sales_df['sale_month_year'] = yoy_sales_df['sale_date'].dt.strftime('%Y-%m')
yoy_sales_df.head()
# Out:
# C:\Users\FSABR\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    borough neighborhood  building_class_category gross_square_feet  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,587
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,495
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,260
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,400
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,394
#
#    year_built  sale_price  sale_date borough_name sale_month_year
# 0        1899      458000 2020-01-31        bronx         2020-01
# 1        1899      275000 2020-03-16        bronx         2020-03
# 2        1910      165000 2020-03-02        bronx         2020-03
# 3        1993           0 2020-03-17        bronx         2020-03
# 4        1995           0 2020-04-06        bronx         2020-04

# %%
yoy_sales_df.dtypes
# Out:
# borough                             Int64
# neighborhood                       object
# building_class_category            object
# gross_square_feet                  object
# year_built                          Int64
# sale_price                          int64
# sale_date                  datetime64[ns]
# borough_name                       object
# sale_month_year                    object
# dtype: object

# %%
yoy_sales_df['year'] = yoy_sales_df['sale_date'].dt.year
yoy_sales_df['month'] = yoy_sales_df['sale_date'].dt.month
yoy_sales_df.head()
# Out:
# C:\Users\FSABR\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\FSABR\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    borough neighborhood  building_class_category gross_square_feet  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,587
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,495
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,260
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,400
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,394
#
#    year_built  sale_price  sale_date borough_name sale_month_year  year  month
# 0        1899      458000 2020-01-31        bronx         2020-01  2020      1
# 1        1899      275000 2020-03-16        bronx         2020-03  2020      3
# 2        1910      165000 2020-03-02        bronx         2020-03  2020      3
# 3        1993           0 2020-03-17        bronx         2020-03  2020      3
# 4        1995           0 2020-04-06        bronx         2020-04  2020      4

# %%
yoy_sales_df['month_name'] = yoy_sales_df['month'].apply(lambda x: calendar.month_abbr[x])
yoy_sales_df.head()
# Out:
# C:\Users\FSABR\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    borough neighborhood  building_class_category gross_square_feet  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,587
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,495
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS             1,260
# 3        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,400
# 4        2     BATHGATE  02 TWO FAMILY DWELLINGS             2,394
#
#    year_built  sale_price  sale_date borough_name sale_month_year  year  \
# 0        1899      458000 2020-01-31        bronx         2020-01  2020
# 1        1899      275000 2020-03-16        bronx         2020-03  2020
# 2        1910      165000 2020-03-02        bronx         2020-03  2020
# 3        1993           0 2020-03-17        bronx         2020-03  2020
# 4        1995           0 2020-04-06        bronx         2020-04  2020
#
#    month month_name
# 0      1        Jan
# 1      3        Mar
# 2      3        Mar
# 3      3        Mar
# 4      4        Apr

# %%
# Set the 'borough' as our index
yoy_sales_df = yoy_sales_df.set_index('borough')
yoy_sales_df.head()
# Out:
#         neighborhood  building_class_category gross_square_feet  year_built  \
# borough
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,587        1899
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,495        1899
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,260        1910
# 2           BATHGATE  02 TWO FAMILY DWELLINGS             2,400        1993
# 2           BATHGATE  02 TWO FAMILY DWELLINGS             2,394        1995
#
#          sale_price  sale_date borough_name sale_month_year  year  month  \
# borough
# 2            458000 2020-01-31        bronx         2020-01  2020      1
# 2            275000 2020-03-16        bronx         2020-03  2020      3
# 2            165000 2020-03-02        bronx         2020-03  2020      3
# 2                 0 2020-03-17        bronx         2020-03  2020      3
# 2                 0 2020-04-06        bronx         2020-04  2020      4
#
#         month_name
# borough
# 2              Jan
# 2              Mar
# 2              Mar
# 2              Mar
# 2              Apr

# %%
yoy_sales_grp_cnt = yoy_sales_df.groupby(['year','month'])['month'].count()
yoy_sales_grp_cnt
# Out:
# year  month
# 2019  1        6457
#       2        5851
#       3        6577
#       4        6898
#       5        7527
#       6        7893
#       7        6950
#       8        7559
#       9        6612
#       10       7296
#       11       6209
#       12       6900
# 2020  1        7169
#       2        6311
#       3        5053
#       4        2807
#       5        3372
#       6        3397
# Name: month, dtype: int64

# %%
yoy_sales_grp_cnt = yoy_sales_grp_cnt.loc[yoy_sales_grp_cnt.index.get_level_values(1) <= 6]
yoy_sales_grp_cnt
# Out:
# year  month
# 2019  1        6457
#       2        5851
#       3        6577
#       4        6898
#       5        7527
#       6        7893
# 2020  1        7169
#       2        6311
#       3        5053
#       4        2807
#       5        3372
#       6        3397
# Name: month, dtype: int64

# %%
months= yoy_sales_grp_cnt.loc[yoy_sales_grp_cnt.index.get_level_values(0) == 2019].index.get_level_values(1)
months
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='month')

# %%
# Plot the world average as a line chart
_2019, = plt.plot(months,yoy_sales_grp_cnt.loc[yoy_sales_grp_cnt.index.get_level_values(0) == 2019], color="blue", label="2019 Sales" )

# Plot the unemployment values for a single country
_2020, = plt.plot(months,yoy_sales_grp_cnt.loc[yoy_sales_grp_cnt.index.get_level_values(0) == 2020], color="green", label="2020 Sales",linestyle='--' )

       
plt.xticks(months,['Jan', 'Feb', 'Mar', 'Apr', 'May','Jun'])       

# Create a legend for our chart
plt.legend(handles=[_2019, _2020], loc="best")
plt.xlabel("Month")
plt.ylabel("Number of Sales")
plt.title("New York Real Estate Sales - Jan- Jun 2019 2020")

# Show the chart
plt.show()
plt.savefig('yoy_sales.png')

# %% [markdown]
# ### Working with 2020 data

# %%
covid_analysis_df = yoy_sales_df.loc[yoy_sales_df['sale_date'] >= '2020-01-01']
covid_analysis_df.head()
# Out:
#         neighborhood  building_class_category gross_square_feet  year_built  \
# borough
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,587        1899
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,495        1899
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,260        1910
# 2           BATHGATE  02 TWO FAMILY DWELLINGS             2,400        1993
# 2           BATHGATE  02 TWO FAMILY DWELLINGS             2,394        1995
#
#          sale_price  sale_date borough_name sale_month_year  year  month  \
# borough
# 2            458000 2020-01-31        bronx         2020-01  2020      1
# 2            275000 2020-03-16        bronx         2020-03  2020      3
# 2            165000 2020-03-02        bronx         2020-03  2020      3
# 2                 0 2020-03-17        bronx         2020-03  2020      3
# 2                 0 2020-04-06        bronx         2020-04  2020      4
#
#         month_name
# borough
# 2              Jan
# 2              Mar
# 2              Mar
# 2              Mar
# 2              Apr

# %%
len(covid_analysis_df.index)
# Out:
# 28109

# %%
bor_sales= covid_analysis_df.groupby(['month','borough_name'])['borough_name'].count()
bor_sales
# Out:
# month  borough_name
# 1      bronx             657
#        brooklyn         2019
#        manhattan        1604
#        queens           2250
#        staten island     639
# 2      bronx             607
#        brooklyn         1753
#        manhattan        1376
#        queens           1933
#        staten island     642
# 3      bronx             480
#        brooklyn         1494
#        manhattan         960
#        queens           1658
#        staten island     461
# 4      bronx             265
#        brooklyn          838
#        manhattan         575
#        queens            861
#        staten island     268
# 5      bronx             291
#        brooklyn         1095
#        manhattan         701
#        queens           1010
#        staten island     275
# 6      bronx             335
#        brooklyn         1091
#        manhattan         765
#        queens           1096
#        staten island     110
# Name: borough_name, dtype: int64

# %%
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May','Jun']
bronx = np.array(bor_sales.loc[bor_sales.index.get_level_values(1) == 'bronx'])
brooklyn = np.array(bor_sales.loc[bor_sales.index.get_level_values(1) == 'brooklyn'])
manhattan = np.array(bor_sales.loc[bor_sales.index.get_level_values(1) == 'manhattan'])
queens = np.array(bor_sales.loc[bor_sales.index.get_level_values(1) == 'queens'])
staten_island = np.array(bor_sales.loc[bor_sales.index.get_level_values(1) == 'staten island'])
ind = [x for x in month]

plt.bar(ind, bronx , width=0.8, label='bronx', color='#0E345B', bottom=brooklyn+manhattan+queens+staten_island)
plt.bar(ind, brooklyn, width=0.8, label='brooklyn', color='#5D8EC1', bottom=manhattan+queens+staten_island)
plt.bar(ind, manhattan, width=0.8, label='manhattan', color='#E7E6E6',bottom=queens+staten_island)
plt.bar(ind, queens, width=0.8, label='queens', color='#FFC000', bottom=staten_island)
plt.bar(ind, staten_island, width=0.8, label='staten island', color='#F0A84C')

plt.xticks(ind, month)
plt.ylabel("sales by boroughs")
plt.xlabel("month")
plt.legend(loc="upper right")
plt.title("NY Sales by Boroughs")

plt.show()
plt.savefig('NY Boroughs 2020')

# %%
covid_analysis_df = covid_analysis_df.loc[(covid_analysis_df['sale_price'] > 1000) & (covid_analysis_df['sale_price'] <=5000000)]
covid_analysis_df.head()
# Out:
#         neighborhood  building_class_category gross_square_feet  year_built  \
# borough
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,587        1899
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,495        1899
# 2           BATHGATE  01 ONE FAMILY DWELLINGS             1,260        1910
# 2           BATHGATE  02 TWO FAMILY DWELLINGS             2,364        1899
# 2           BATHGATE  02 TWO FAMILY DWELLINGS             3,204        1995
#
#          sale_price  sale_date borough_name sale_month_year  year  month  \
# borough
# 2            458000 2020-01-31        bronx         2020-01  2020      1
# 2            275000 2020-03-16        bronx         2020-03  2020      3
# 2            165000 2020-03-02        bronx         2020-03  2020      3
# 2            734000 2020-04-22        bronx         2020-04  2020      4
# 2            645000 2020-01-28        bronx         2020-01  2020      1
#
#         month_name
# borough
# 2              Jan
# 2              Mar
# 2              Mar
# 2              Apr
# 2              Jan

# %%
med_sls = covid_analysis_df[['borough_name','sale_price','month']]
med_sls.head()
# Out:
#         borough_name  sale_price  month
# borough
# 2              bronx      458000      1
# 2              bronx      275000      3
# 2              bronx      165000      3
# 2              bronx      734000      4
# 2              bronx      645000      1

# %%
med_sls_cnt = med_sls.groupby(['month','borough_name']).median()
med_sls_cnt
# Out:
#                      sale_price
# month borough_name
# 1     bronx            495000.0
#       brooklyn         800000.0
#       manhattan       1035000.0
#       queens           630000.0
#       staten island    530000.0
# 2     bronx            486000.0
#       brooklyn         800000.0
#       manhattan        995000.0
#       queens           569000.0
#       staten island    549000.0
# 3     bronx            562500.0
#       brooklyn         816500.0
#       manhattan       1025000.0
#       queens           615000.0
#       staten island    537500.0
# 4     bronx            560038.0
#       brooklyn         770178.0
#       manhattan       1100000.0
#       queens           630000.0
#       staten island    575000.0
# 5     bronx            519000.0
#       brooklyn         822391.5
#       manhattan        952500.0
#       queens           600000.0
#       staten island    542636.5
# 6     bronx            520000.0
#       brooklyn         822955.0
#       manhattan        896000.0
#       queens           590000.0
#       staten island    575000.0

# %%
bronx = med_sls_cnt.loc[med_sls_cnt.index.get_level_values(1) == 'bronx'].tolist()
bronx
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-3b4f0c8347c5> in <module>
# ----> 1 bronx = med_sls_cnt.loc[med_sls_cnt.index.get_level_values(1) == 'bronx'].tolist()
#       2 bronx
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
N = 6
#men_means = (20, 35, 30, 35, 27)
#women_means = (25, 32, 34, 20, 25)
bronx = np.array(med_sls_cnt.loc[med_sls_cnt.index.get_level_values(1) == 'bronx'])
brooklyn = np.array(med_sls_cnt.loc[med_sls_cnt.index.get_level_values(1) == 'brooklyn'])
manhattan = np.array(med_sls_cnt.loc[med_sls_cnt.index.get_level_values(1) == 'manhattan'])
queens = np.array(med_sls_cnt.loc[med_sls_cnt.index.get_level_values(1) == 'queens'])
staten_island = np.array(med_sls_cnt.loc[med_sls_cnt.index.get_level_values(1) == 'staten island'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, bronx, width, label='Bronx')
plt.bar(ind + width, brooklyn, width,label='Brooklyn')
plt.bar(ind, manhattan, width, label='Manhattan')
plt.bar(ind + width, queens, width,label='Queens')
plt.bar(ind, staten_island, width, label='Staten Island')

plt.ylabel('Median Sales Price')
plt.title('NY Median Sales Price by Borough Jan-Jun 2020')

plt.xticks(ind + width / 2, ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'))
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-cb7b888b6454> in <module>
#      10 ind = np.arange(N)
#      11 width = 0.35
# ---> 12 plt.bar(ind, bronx, width, label='Bronx')
#      13 plt.bar(ind + width, brooklyn, width,label='Brooklyn')
#      14 plt.bar(ind, manhattan, width, label='Manhattan')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2393                 edgecolor=e,
#    2394                 linewidth=lw,
# -> 2395                 label='_nolegend_',
#    2396                 )
#    2397             r.update(kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     725         """
#     726
# --> 727         Patch.__init__(self, **kwargs)
#     728
#     729         self._x0 = xy[0]
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      87         self.set_fill(fill)
#      88         self.set_linestyle(linestyle)
# ---> 89         self.set_linewidth(linewidth)
#      90         self.set_antialiased(antialiased)
#      91         self.set_hatch(hatch)
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in set_linewidth(self, w)
#     393                 w = mpl.rcParams['axes.linewidth']
#     394
# --> 395         self._linewidth = float(w)
#     396         # scale the dash pattern by the linewidth
#     397         offset, ls = self._us_dashes
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
max_sales = covid_analysis_df["sale_price"].max()
max_sales
# Out:
# 5000000

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Temperatures at LAX')
ax1.set_ylabel('Temperature (°F)')
ax1.boxplot(covid_analysis_df['sale_price'])
plt.show()
